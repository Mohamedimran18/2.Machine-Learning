# %%
import pandas as pd

# %%
 dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset = pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes' ]]

# %%
dependent = dataset[['charges']]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid = {'kernel':['rbf','linear'],
              'C':[10,100,1000],'gamma':['auto','scale']}

grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3, n_jobs=-1)

grid.fit(independent, dependent)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# C:\Users\moham\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 100, 1000], 'gamma': ['auto', 'scale'],
#                          'kernel': ['rbf', 'linear']},
#              verbose=3)

# %%
re = grid.cv_results_

print("The R_score value for the best parameter{}:".format(grid.best_params_))
# Out:
# The R_score value for the best parameter{'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}:

# %%
 table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        0.291442      0.006221         0.122437        0.003108       10
# 1        0.267062      0.013800         0.038584        0.004657       10
# 2        0.247991      0.003808         0.119874        0.002279       10
# 3        0.249674      0.013859         0.035672        0.001479       10
# 4        0.271322      0.004131         0.122111        0.003032      100
# 5        0.548957      0.034516         0.036081        0.002106      100
# 6        0.243158      0.002830         0.119563        0.003835      100
# 7        0.530005      0.010898         0.037394        0.004375      100
# 8        0.360293      0.018356         0.116573        0.008203     1000
# 9        1.929100      0.204237         0.029811        0.007458     1000
# 10       0.290038      0.020436         0.127167        0.011700     1000
# 11       1.676591      0.161578         0.019928        0.006945     1000
#
#    param_gamma param_kernel  \
# 0         auto          rbf
# 1         auto       linear
# 2        scale          rbf
# 3        scale       linear
# 4         auto          rbf
# 5         auto       linear
# 6        scale          rbf
# 7        scale       linear
# 8         auto          rbf
# 9         auto       linear
# 10       scale          rbf
# 11       scale       linear
#
#                                                params  split0_test_score  \
# 0         {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}          -0.113791
# 1      {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}          -0.018943
# 2        {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}          -0.110409
# 3     {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}          -0.018943
# 4        {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}          -0.100012
# 5     {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.559313
# 6       {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}          -0.160182
# 7    {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.559313
# 8       {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}          -0.080692
# 9    {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}           0.736398
# 10     {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}          -0.155430
# 11  {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}           0.736398
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0           -0.110741          -0.079156          -0.103389
# 1            0.029886           0.022167           0.003112
# 2           -0.097459          -0.074488          -0.099597
# 3            0.029886           0.022167           0.003112
# 4           -0.098456          -0.072981          -0.096615
# 5            0.521798           0.547691           0.538805
# 6           -0.107253          -0.123430          -0.137753
# 7            0.521798           0.547691           0.538805
# 8           -0.054347          -0.062876          -0.079329
# 9            0.675162           0.680002           0.699377
# 10          -0.098267          -0.123724          -0.137137
# 11           0.675162           0.680002           0.699377
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -0.106488        -0.102713        0.012303               10
# 1           -0.066653        -0.006086        0.034672                5
# 2           -0.124428        -0.101276        0.016459                9
# 3           -0.066653        -0.006086        0.034672                5
# 4           -0.102232        -0.094059        0.010699                8
# 5            0.508518         0.535225        0.018122                3
# 6           -0.209551        -0.147634        0.035511               12
# 7            0.508518         0.535225        0.018122                3
# 8           -0.117983        -0.079045        0.021865                7
# 9            0.677952         0.693778        0.022955                1
# 10          -0.206405        -0.144193        0.036262               11
# 11           0.677952         0.693778        0.022955                1

# %%
 age_input=float(input("Age:"))
 bmi_input=float(input("BMI:"))
 children_input=float(input("Children:"))
 sex_male_input=int(input("Sex Male 0 or 1:"))
 smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 54
# BMI: 45
# Children: 2
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1: 1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[36101.21654516]
# C:\Users\moham\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
